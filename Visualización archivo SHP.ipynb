# %% [markdown]
# <a href="https://colab.research.google.com/github/Miranda-Merino-Irigoyen-Jorge-Missael/Piloto/blob/main/Visualizaci%C3%B3n%20archivo%20SHP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualizar archivos SHP con Python

# %% [markdown]
# Primero descargaremos las bibliotecas necesarias para la visualización y manejo de los datos.

# %%
pip install geopandas

# %% [markdown]
# Como nos encontramos trabajando en Google Colab debemos subir todos los archivos relacionados al SHP para poder usarlos.

# %%
import geopandas as gpd
import pandas as pd
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-27b08cee-3713-46d2-95cb-378892fb4d36" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27b08cee-3713-46d2-95cb-378892fb4d36">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Ahora vamos a ver la ruta local que se ha creado, ya que vamos a necesitarlas:

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'Metrobus_estaciones (1).shp', 'Metrobus_estaciones.cpg', 'Metrobus_estaciones.dbf', 'Metrobus_estaciones.prj', 'Metrobus_estaciones.shp', 'Metrobus_estaciones.shx', 'sample_data']

# %% [markdown]
# Cargamos el archivo SHP y mostramos los primeros registros para verificar que nos encontramos en el archivo correcto.

# %%
# Ruta del archivo SHP subido
ruta_archivo = "Metrobus_estaciones.shp"

# Cargar el archivo
datos = gpd.read_file(ruta_archivo)

# Ver los primeros registros
print(datos.head())
# Out:
#     SISTEMA        NOMBRE LINEA   EST CVE_EOD17               TIPO  \
# 0  Metrobús         París    07  None      None  Servicio temporal
# 1  Metrobús       Reforma    07  None      None  Servicio temporal
# 2  Metrobús      Hamburgo    07  None      None  Servicio temporal
# 3  Metrobús  El Ahuehuete    07  None      None  Servicio temporal
# 4  Metrobús      El Ángel    07  None      None  Servicio temporal
#
#     ALCALDIAS     AÑO CVE_EST                        geometry
# 0  Cuauhtémoc  2023.0    None  POINT Z (-99.15591 19.43239 0)
# 1  Cuauhtémoc  2023.0    None  POINT Z (-99.15854 19.43111 0)
# 2  Cuauhtémoc  2023.0    None   POINT Z (-99.1628 19.42917 0)
# 3  Cuauhtémoc  2023.0    None  POINT Z (-99.16506 19.42807 0)
# 4  Cuauhtémoc  2023.0    None  POINT Z (-99.16866 19.42642 0)

# %% [markdown]
# A cotinuación mostramos todas las estaciones del metrobus con el año en el que se dio la apertura de dicha estación y en que linea del metrobus se encuentra.

# %%
pd.set_option('display.max_rows', None)
print(datos[['NOMBRE', 'AÑO', 'LINEA']])
# Out:
#                            NOMBRE     AÑO LINEA
# 0                           París  2023.0    07
# 1                         Reforma  2023.0    07
# 2                        Hamburgo  2023.0    07
# 3                    El Ahuehuete  2023.0    07
# 4                        El Ángel  2023.0    07
# 5                        La Diana  2023.0    07
# 6                     Chapultepec  2023.0    07
# 7                Alameda Tacubaya  2023.0    07
# 8                     De La Salle  2023.0    07
# 9                     De La Salle  2023.0    07
# 10                    Chapultepec  2023.0    07
# 11                       La Diana  2023.0    07
# 12                       El Ángel  2023.0    07
# 13                   El Ahuehuete  2023.0    07
# 14                       Hamburgo  2023.0    07
# 15                        Reforma  2023.0    07
# 16                          París  2023.0    07
# 17                  Aeropuerto T1     NaN    04
# 18                  Aeropuerto T2     NaN    04
# ...
